# %%
import os
from preprocess_data import preprocess_song

# %%
file_path = '../musdb18/wav/train'
files = [os.path.join(file_path, file_name) for file_name in os.listdir(file_path)]

# %%
for file in files:
    preprocess_song(file, f'../musdb18/stft')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for file in files:
# ----> 2     preprocess_song(file, f'../musdb18/stft')
#
# File ~/python_projects/UAI_final_task/data_preproccess/preprocess_data.py:154, in preprocess_song(input_path, output_dir)
#     151 other_mag = pad_mag(to_mag(other_chunk)).astype(np.float32)
#     152 vocals_mag = pad_mag(to_mag(vocals_chunk)).astype(np.float32)
# --> 154 np.savez_compressed(
#     155     os.path.join(output_dir, f"{name}_{i:02d}.npz"),
#     156     mix=mix_mag,
#     157     drums=drums_mag,
#     158     bass=bass_mag,
#     159     other=other_mag,
#     160     vocals=vocals_mag,
#     161     sr=GLOBAL_RATE,
#     162     frame_length=1024,
#     163     frame_steps=256
#     164 )
#
# File ~/python_projects/UAI_final_task/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:753, in savez_compressed(file, allow_pickle, *args, **kwds)
#     681 @array_function_dispatch(_savez_compressed_dispatcher)
#     682 def savez_compressed(file, *args, allow_pickle=True, **kwds):
#     683     """
#     684     Save several arrays into a single file in compressed ``.npz`` format.
#     685
#    (...)    751
#     752     """
# --> 753     _savez(file, args, kwds, True, allow_pickle=allow_pickle)
#
# File ~/python_projects/UAI_final_task/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:786, in _savez(file, args, kwds, compress, allow_pickle, pickle_kwargs)
#     784         # always force zip64, gh-10776
#     785         with zipf.open(fname, 'w', force_zip64=True) as fid:
# --> 786             format.write_array(fid, val,
#     787                                allow_pickle=allow_pickle,
#     788                                pickle_kwargs=pickle_kwargs)
#     789 finally:
#     790     zipf.close()
#
# File ~/python_projects/UAI_final_task/.venv/lib/python3.12/site-packages/numpy/lib/_format_impl.py:777, in write_array(fp, array, version, allow_pickle, pickle_kwargs)
#     773 else:
#     774     for chunk in numpy.nditer(
#     775             array, flags=['external_loop', 'buffered', 'zerosize_ok'],
#     776             buffersize=buffersize, order='C'):
# --> 777         fp.write(chunk.tobytes('C'))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1206, in _ZipWriteFile.write(self, data)
#    1204 self._crc = crc32(data, self._crc)
#    1205 if self._compressor:
# -> 1206     data = self._compressor.compress(data)
#    1207     self._compress_size += len(data)
#    1208 self._fileobj.write(data)
#
# KeyboardInterrupt:
